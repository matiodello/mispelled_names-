# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
# EXCEL
path = 'excel_ordenado.xlsx'

df = pd.read_excel(path)#, index_col='objectid')
# si luego de pd.real_excel(path, , index_col='Datos') , index_col='NameColumn'significa que indexa las filas segun el valor de alguna columna
df
# Out:
# C:\Users\ACER NITRO 5\AppData\Roaming\Python\Python39\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       APELLIDO         NOMBRE_COMPLETO          NOMBRE         DNI  \
# 0       RODAS           RODAS  ROXANA          ROXANA   20622020.0
# 1    RODRIGUEZ       RODRIGUEZ ROMINA          ROMINA   31057427.0
# 2      SUAREZ            SUAREZ  LUIS            LUIS   24073589.0
# 3      ANGELO   ANGELO  ELIANA ANDREA   ELIANA ANDREA   23231601.0
# 4    ESPINOSA        ESPINOSA  DEBORA          DEBORA   27959735.0
# ..         ...                     ...             ...         ...
# 372     CORTEZ       CORTEZ ANA YANINA      ANA YANINA  34767742.0
# 373     ROLDAN           ROLDAN BRENDA          BRENDA  41152709.0
# 374  PONTICOVA        PONTICOVA WALTER          WALTER  24172552.0
# ...

# %%
#LIMPIANDO CARACTERES ESPECIALES

L_calle = 'NOMBRE_COMPLETO'

df[L_calle] = df[L_calle].str.replace('Ñ','N',regex = True)
df[L_calle] = df[L_calle].str.replace('Á','A',regex = True)
df[L_calle] = df[L_calle].str.replace('É','E',regex = True)
df[L_calle] = df[L_calle].str.replace('Í','I',regex = True)
df[L_calle] = df[L_calle].str.replace('Ó','O',regex = True)
df[L_calle] = df[L_calle].str.replace('Ú','U',regex = True)
df[L_calle] = df[L_calle].str.replace('Ü','U',regex = True)
df[L_calle] = df[L_calle].str.replace('á','a',regex = True)
df[L_calle] = df[L_calle].str.replace('é','e',regex = True)
df[L_calle] = df[L_calle].str.replace('í','i',regex = True)
df[L_calle] = df[L_calle].str.replace('ó','o',regex = True)
df[L_calle] = df[L_calle].str.replace('ú','u',regex = True)
df[L_calle] = df[L_calle].str.replace('ñ','n',regex = True)
#df[L_calle] = df[L_calle].str.replace('[/]',' ',regex = True)
#df[L_calle] = df[L_calle].str.replace('[-(><!#$:)/.;,?¢¶âš™äëöüÿ»&+#³Ïï¡☐¦‡•…□▭▯ðÿ·€—§-±¾ž“‘©°˜ðšÿ™â¤¥½œ¼£üç)]','',regex = True)
df
# Out:
#       APELLIDO         NOMBRE_COMPLETO          NOMBRE         DNI  \
# 0       RODAS           RODAS  ROXANA          ROXANA   20622020.0
# 1    RODRIGUEZ       RODRIGUEZ ROMINA          ROMINA   31057427.0
# 2      SUAREZ            SUAREZ  LUIS            LUIS   24073589.0
# 3      ANGELO   ANGELO  ELIANA ANDREA   ELIANA ANDREA   23231601.0
# 4    ESPINOSA        ESPINOSA  DEBORA          DEBORA   27959735.0
# ..         ...                     ...             ...         ...
# 372     CORTEZ       CORTEZ ANA YANINA      ANA YANINA  34767742.0
# 373     ROLDAN           ROLDAN BRENDA          BRENDA  41152709.0
# 374  PONTICOVA        PONTICOVA WALTER          WALTER  24172552.0
# 375    FARIAS      FARIAS  JOSE RUBEN      JOSE RUBEN   39253113.0
# 376   URSALIAN         URSALIAN ALICIA          ALICIA   6492759.0
#
#                                               PRODUCTO  \
# 0                                          3 FRAZADAS
# ...

# %%
# Esta línea permite descargar el archivo ya limpio en formato XLSX (si deseas descargarlo como CSV tendrás que indicarlo de la manera adecuada)
# Te lo guarda en la dirección donde esté alojado el script.

df.to_excel('JULIO-AGOSTO 2022_LIMPIO.xlsx')
